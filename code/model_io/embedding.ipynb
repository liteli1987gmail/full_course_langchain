# %% [markdown]
# # 2.1.3 文本嵌入模型 (Text Embedding Models)

# %% [markdown]
# ### 安装和设置密钥

# %%
# %pip install openai langchain

# %% [markdown]
# ### 安装和设置密钥

# %%
from langchain.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(openai_api_key = "")
res = embeddings.embed_query("This is an apple.")
res
# Out:
# [0.012008527293801308,
#  -0.001835253438912332,
#  0.00145026296377182,
#  -0.0030227703973650932,
#  -0.005661344155669212,
#  0.005086636636406183,
#  -0.024550484493374825,
#  -0.0012430825736373663,
#  0.012859474867582321,
#  -0.03881338983774185,
#  0.0046262359246611595,
#  0.021337203681468964,
#  -0.020435452461242676,
#  0.008992106653749943,
#  -0.011811666190624237,
#  0.02291209250688553,
#  0.025541139766573906,
#  -0.013348452746868134,
#  0.013030934147536755,
#  -0.011259185150265694,
#  -0.03647645562887192,
#  0.007048897445201874,
#  0.014478816650807858,
#  0.004889775533229113,
#  0.005439081694930792,
#  0.011945023201406002,
#  0.010655900463461876,
#  -0.016231514513492584,
#  0.03271704539656639,
#  -0.005026308353990316,
#  0.017323777079582214,
#  -0.014745531603693962,
#  -0.00810305681079626,
#  0.0014105732552707195,
#  -0.01037648506462574,
#  -0.015139253810048103,
#  -0.008052254095673561,
#  -0.022404063493013382,
#  0.0030513470992445946,
# ...
